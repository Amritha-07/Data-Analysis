# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
import random
import statistics
from scipy.stats import norm

# %%
df = pd.read_excel(r"Marketing strategies_2.xlsx")

# %%
df
# Out:
#      Social Media  Tele Marketing  TV Ads  Pop-up Ads  Posters  Airtel  \
# 0               2              -2       0          -1       -2       1
# 1               2              -2      -1          -2        0       2
# 2               1               1       2           0        1       1
# 3               0              -2       1          -2        0       2
# 4               2              -2       0           0       -1       2
# ..            ...             ...     ...         ...      ...     ...
# 155             0              -1       1          -2        0       2
# 156             1              -1       2          -2        2       0
# 157             2              -2       0           1       -2       1
# 158             2               1       0          -1        2       0
# 159             2               0      -1          -1       -1       1
#
#      YouTube Marketing Technique
# 0          2      Public reviews
# 1          1        Social media
# 2          2              TV ADs
# 3          2        Social media
# 4          1         Sponsorship
# ..       ...                 ...
# 155        2              TV ADs
# 156        2        Social media
# 157        0               Blogs
# 158        2        Social media
# 159        2              TV ADs
#
# [160 rows x 8 columns]

# %%
counts1 = pd.DataFrame(df["Marketing Technique"].value_counts(sort=True))
print(counts1)
# Out:
#                 Marketing Technique
# Social media                     80
# TV ADs                           29
# Blogs                            21
# Posters                          11
# Public reviews                   10
# Sponsorship                       9

# %%
data = df["Social Media"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = -1
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [2, 2, 1, 0, 2, 2, 2, 1, 1, 1, 2, 1, 0, 0, 1, 1, 0, 0, 1, 2, 2, 0, 1, -1, 2, 1, 1, 1, 1, 0, 0, 2, 2, 0, -1, 0, 1, 2, 1, 1, 2, 1, 2, 2, 1, 2, 1, 0, 0, 1, 0, 1, 1, 0, 2, -1, -2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0, -1, -1, 1, 1, 1, 2, 1, 0, 0, 0, 1, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 1, 2, 2, 2, 2, 2, -1, 1, -1, -2, 2, 2, 2, 1, 2, -2, -1, -2, -2, 2, 0, 2, 2, 2, 2, 2, 2, 0, 1, 2, 2, 1, 0, 0, 2, 0, 1, -1, 1, -1, 0, -1, 2, 2, -1, 2, 2, -1, 2, 1, 2, 1, 1, 2, 2, 0, 1, 2, 2, 2]
# Ssample:  [2, 2, 2, 1, 2, 2, 1, 2, 1, 2, -2, 2, 2, 2, 1, 0, 0, 2, 1, 1]
#
# Population Mean(μ):  -1
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  1.00625
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  10.988683809947396
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  10.988683809947396 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0

# %%
data = df["Tele Marketing"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = 1
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [-2, -2, 1, -2, -2, 1, -2, -1, -1, 1, 0, 0, 0, 1, -1, -1, -2, 0, -2, -2, -2, -2, -1, -1, 2, -1, -1, 0, 0, 0, -2, -1, -1, -1, 0, -1, -2, -1, -1, -2, -1, -1, -2, -1, -1, 2, 0, -2, -2, -2, -2, -1, -2, -1, 2, -1, -2, 2, 2, 2, -2, -2, -2, -2, -2, -2, 0, 1, -2, -2, 0, 1, 1, 1, 0, 0, 0, -1, -2, -1, -1, -1, -1, -2, -1, 0, 0, -1, -2, 0, 0, -1, 1, -1, 2, 1, 1, -2, -2, -2, 0, -1, -2, -2, 0, 0, -1, -2, 1, 0, -2, 1, -2, -1, -1, 0, -2, 0, 0, -2, -1, -2, -2, 0, -2, 0, -2, -1, -2, -2, -1, -2, -1, -2, 2, -2, -2, -1, -2, -2, -2, 0, -2, 0, -2, 0, -2, -2, 0, 0, -2, -2, -1, -2, -1, -1, -1, -2, 1, 0]
# Ssample:  [1, 0, -2, -2, -2, -1, -1, -2, -2, -2, -2, -2, -2, 0, -2, -1, -2, 1, -2, 1]
#
# Population Mean(μ):  1
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  -0.85625
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  -10.167099973689647
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  -10.167099973689647 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0

# %%
data = df["TV Ads"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = 1
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [0, -1, 2, 1, 0, 1, 0, 2, 0, 0, 1, 0, -1, 2, 0, 1, -1, -1, -1, 0, 1, 0, 0, 0, 2, 0, -2, 1, 1, 1, -2, 2, 1, 1, -2, 1, -2, 1, 0, -1, 0, 0, 0, -1, 1, 2, 0, -1, 1, -1, -2, 1, 0, 1, 2, -1, -2, 2, 2, 2, 2, 0, -1, 0, 0, -2, -2, -2, 0, -2, -2, 0, -2, -2, 0, 1, 2, -1, 0, 0, 0, 1, 0, 1, 0, 1, 0, 1, -2, 0, -2, 0, -2, -1, -2, -1, 0, -1, 0, 1, 0, 0, -2, -2, -1, 1, 1, 2, 2, 1, 1, 1, 2, 2, 0, 2, 1, 2, -1, 0, 2, -2, 1, -2, 1, -1, 1, 0, 1, 1, 0, -2, -1, 1, 2, -1, 0, 0, 1, 0, -1, 1, 1, -1, -1, 1, 1, 2, -1, 2, 2, 0, 0, 1, 0, 1, 2, 0, 0, -1]
# Ssample:  [0, -1, -1, 0, 0, -1, 0, 2, 1, 1, 0, 2, 2, 2, 0, -1, -1, -2, 1, 2]
#
# Population Mean(μ):  1
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  0.125
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  -4.792572378170203
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  -4.792572378170203 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0

# %%
data = df["Pop-up Ads"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = 1
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [-1, -2, 0, -2, 0, -1, -1, -1, 0, -1, 0, -1, -2, 0, -2, 0, -2, -1, 2, -1, -1, -1, 0, -2, 2, 0, -2, -1, 0, -2, -2, -1, 0, 0, -2, 0, -1, -2, -2, 1, -2, -1, -1, -1, -2, 2, 1, -2, 0, 0, -2, 0, -2, -1, 2, -2, 0, 2, 2, 2, -2, -2, 0, -2, -2, -2, -2, -2, -2, -2, -2, -2, -2, -2, -2, -2, 2, -2, 1, 1, -2, -1, -1, -1, 0, 0, 0, -1, -2, -1, -1, -2, -2, -2, -2, -2, -2, -2, 0, -1, 1, 0, -2, -1, -2, -2, -1, -1, -2, -1, 0, 0, 0, -2, 2, -2, -1, -2, -2, 1, 0, 0, -2, -1, -2, 0, -1, 1, -2, -1, -2, -2, -2, -2, 0, -2, -2, -2, -2, 1, -2, 0, -1, 1, -2, -1, -2, -2, 1, 2, -2, -2, -1, -2, -1, -2, -2, 1, -1, -1]
# Ssample:  [0, -2, -2, 1, -2, 2, -1, -1, -1, -2, -2, -2, -2, 0, 0, 2, -2, -1, 0, 0]
#
# Population Mean(μ):  1
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  -0.93125
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  -10.57789189181852
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  -10.57789189181852 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0

# %%
data = df["Posters"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = 1
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [-2, 0, 1, 0, -1, 0, -1, -2, -1, 0, 2, 1, -2, 1, -2, 1, -2, -1, -1, -1, -1, 0, 1, -2, 2, -1, 0, 1, 1, 1, 0, -1, -1, 1, -1, -1, 0, -2, -1, 1, 0, -1, 1, -1, 1, 2, 0, -2, 0, -1, 1, -1, -2, -1, 2, 0, 0, 2, 2, 2, -2, -2, -2, -2, -2, -2, -2, -2, -2, -2, 0, -2, -2, 0, 1, 1, 2, 0, 1, 0, 0, 0, 0, 0, -2, 1, 0, -1, -2, 1, -2, 1, -2, -1, 0, -1, -2, 0, -1, 0, 0, -2, -2, -1, -2, -2, 0, 1, 0, 2, 0, -2, -1, 0, -1, 2, -2, 2, 2, -2, -1, -1, -2, -2, -1, -1, -1, -1, -2, -2, -2, -2, 2, 1, 1, -1, -2, -2, -2, 2, -2, -2, 0, 2, 0, -1, -2, 2, -1, 0, 0, -1, 0, -1, 1, 0, 2, -2, 2, -1]
# Ssample:  [0, 2, 0, 1, 0, 2, -2, -2, -2, -1, 2, -2, -2, 0, -1, -1, -2, -2, 1, -1]
#
# Population Mean(μ):  1
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  -0.4375
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  -7.873511764136763
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  -7.873511764136763 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0

# %%
data = df["Airtel"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = 0
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [1, 2, 1, 2, 2, 1, 0, 2, 2, 0, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 1, 1, 0, 1, 2, 0, 1, 2, 1, 1, 0, 2, 1, 1, 1, 2, 1, 1, 1, 1, 2, 0, 0, 2, 2, 2, 0, 2, 2, 0, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 1, 1, 1, 0, 1, 2, 1, 1, 2, 1, 2, 2, 1, 2, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 1, 1, 2, 2, 0, 2, 1, 2, 0, 1, 0, 0, 0, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 1, 2, 1, 0, 2, 1, 1, 1, 2, 0, 2, 1, 1, 2, 2, 1, 0, 1, 2, 2, 0, 2, 0, 1, 0, 1]
# Ssample:  [2, 1, 1, 2, 2, 2, 1, 0, 1, 1, 2, 0, 1, 1, 2, 2, 2, 2, 1, 2]
#
# Population Mean(μ):  0
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  1.39375
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  7.633883145228253
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  7.633883145228253 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0

# %%
data = df["YouTube"]
data = list(data)
print("Population: ", data)

sample = random.sample(data, 20)
print("Ssample: ", sample)

population_mean = 0
population_stddev = 1
n = 30
sample_mean = statistics.mean(data)
sample_stddev = statistics.stdev(data)
print("\nPopulation Mean(μ): ", population_mean, "\n\nPopulation Standard Deviation(σ): ", population_stddev)
print("\nNumber of Samples(n):", n, "\n\nSample Mean(x̅): ", sample_mean)

x_axis = np.arange(-5, 5)
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(x_axis, norm.pdf(x_axis, population_mean, population_stddev))
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('μ', fontsize='16')
plt.ylabel(' Probability ', fontsize='12')
plt.show() 

Z_score = (sample_mean - population_mean)/(population_stddev / math.sqrt(n))
print("For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]")
print("\nZ = ", Z_score)

C = input("\nChoose confidence value(90%, 95%, 99%): ")
C = int(C) 
if(C==90):
    print("\n\tThen α-value is 10% (or) 0.1")
    Z = 1.645
elif (C==95):
    print("\n\tThen α-value is 5% (or) 0.05")
    Z = 1.960
elif (C==99):
    print("\n\tThen α-value is 1% (or) 0.01")
    Z = 2.576
elif (C!=90, 95, 99):
    print("\n\nEnter from the three values!!")
    exit()
print("\nFor the claim, the Z-score right tail test is", Z)

print("\nResult: ")
k = -Z
if(Z_score >  Z or (Z_score < k)):
    print("\n\tHere, ", Z_score,"is greater than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
elif((Z_score < k)):
    print("\n\tHere, ", Z_score,"is lesser than ", Z)
    print("\n\t=> Hence, We reject NULL Hypothesis, H0")
else:
    print("\n\tHere, ", Z_score,"is less than ", Z)
    print("\n\t=> Hence, We will not reject NUll hypothesis, H0")
# Out:
# Population:  [2, 1, 2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 1, 2, 2, 1, 1, 0, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2, 1, 2, 2, 2, 0, 2, 1, 0, 2, 2, 2, 1, 2, 0, 0, 1, 0, 1, 2, 0, 2, 1, 1, 0, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 1, 1, 2, 2, 0, 2, 1, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 2, 1, 0, 1, 1, 1, 2, 2, 1, 2, 2, 0, 2, 2]
# Ssample:  [2, 2, 1, 2, 2, 1, 2, 0, 2, 2, 2, 1, 2, 2, 2, 0, 1, 2, 1, 1]
#
# Population Mean(μ):  0
#
# Population Standard Deviation(σ):  1
#
# Number of Samples(n): 30
#
# Sample Mean(x̅):  1.5875
# For performing Z-test, we use the following formula: [Z = (x̅ - μ)/(σ / √n)]
#
# Z =  8.695095600394513
#
# Choose confidence value(90%, 95%, 99%): 99
#
# 	Then α-value is 1% (or) 0.01
#
# For the claim, the Z-score right tail test is 2.576
#
# Result:
#
# 	Here,  8.695095600394513 is greater than  2.576
#
# 	=> Hence, We reject NULL Hypothesis, H0
