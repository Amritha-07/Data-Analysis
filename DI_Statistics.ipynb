# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
import random
import statistics
from scipy.stats import norm

# %%
df = pd.read_excel(r"Marketing strategies_3.xlsx")

# %%
df
# Out:
#     Social Media Tele Marketing   TV Ads Pop-up ADs  Posters  \
# 0           Most          Least  Average       Less    Least
# 1           Most          Least     Less      Least  Average
# 2           More           More     Most    Average     More
# 3        Average          Least     More      Least  Average
# 4           Most          Least  Average    Average     Less
# ..           ...            ...      ...        ...      ...
# 155      Average           Less     More      Least  Average
# 156         More           Less     Most      Least     Most
# 157         Most          Least  Average       More    Least
# 158         Most           More  Average       Less     Most
# 159         Most        Average     Less       Less     Less
#
#     Marketing Technique
# 0        Public reviews
# 1          Social media
# 2                TV ADs
# 3          Social media
# 4           Sponsorship
# ..                  ...
# 155              TV ADs
# 156        Social media
# ...

# %%
counts1 = pd.DataFrame(df["Social Media"].value_counts(sort=True))
p1 = counts1["Social Media"].plot.pie(figsize = (5, 5), label='')
plt.legend(bbox_to_anchor=(2, 0), loc="lower right", bbox_transform=plt.gcf().transFigure)
plt.title("Social Media")
plt.show()
print(counts1)
# Out:
#          Social Media
# Most               69
# More               46
# Average            27
# Less               13
# Least               5

# %%
counts1 = pd.DataFrame(df["Tele Marketing"].value_counts(sort=True))
p1 = counts1["Tele Marketing"].plot.pie(figsize = (5, 5), label='')
plt.legend(bbox_to_anchor=(2, 0), loc="lower right", bbox_transform=plt.gcf().transFigure)
plt.title("Tele Marketing")
plt.show()
print(counts1)
# Out:
#          Tele Marketing
# Least                62
# Less                 43
# Average              33
# More                 14
# Most                  8

# %%
counts1 = pd.DataFrame(df["TV Ads"].value_counts(sort=True))
p1 = counts1["TV Ads"].plot.pie(figsize = (5, 5), label='')
plt.legend(bbox_to_anchor=(2, 0), loc="lower right", bbox_transform=plt.gcf().transFigure)
plt.title("TTV Ads")
plt.show()
print(counts1)
# Out:
#          TV Ads
# Average      48
# More         41
# Less         25
# Most         24
# Least        22

# %%
counts1 = pd.DataFrame(df["Pop-up ADs"].value_counts(sort=True))
p1 = counts1["Pop-up ADs"].plot.pie(figsize = (5, 5), label='')
plt.legend(bbox_to_anchor=(2, 0), loc="lower right", bbox_transform=plt.gcf().transFigure)
plt.title("Pop-up ADs")
plt.show()
print(counts1)
# Out:
#          Pop-up ADs
# Least            71
# Less             38
# Average          30
# More             12
# Most              9

# %%
counts1 = pd.DataFrame(df["Posters"].value_counts(sort=True))
p1 = counts1["Posters"].plot.pie(figsize = (5, 5), label='')
plt.legend(bbox_to_anchor=(2, 0), loc="lower right", bbox_transform=plt.gcf().transFigure)
plt.title("Posters")
plt.show()
print(counts1)
# Out:
#          Posters
# Least         46
# Less          37
# Average       36
# More          23
# Most          18

# %%
counts1 = pd.DataFrame(df["Marketing Technique"].value_counts(sort=True))
p1 = counts1["Marketing Technique"].plot.pie(figsize = (5, 5), label='')
plt.legend(bbox_to_anchor=(2, 0), loc="lower right", bbox_transform=plt.gcf().transFigure)
plt.title("Marketing Technique")
plt.show()
print(counts1)
# Out:
#                 Marketing Technique
# Social media                     80
# TV ADs                           29
# Blogs                            21
# Posters                          11
# Public reviews                   10
# Sponsorship                       9

# %%
df =  pd.get_dummies(df)
df
# Out:
#      Social Media_Average  Social Media_Least  Social Media_Less  \
# 0                       0                   0                  0
# 1                       0                   0                  0
# 2                       0                   0                  0
# 3                       1                   0                  0
# 4                       0                   0                  0
# ..                    ...                 ...                ...
# 155                     1                   0                  0
# 156                     0                   0                  0
# 157                     0                   0                  0
# 158                     0                   0                  0
# 159                     0                   0                  0
#
#      Social Media_More  Social Media_Most  Tele Marketing_Average  \
# 0                    0                  1                       0
# ...

# %%
df_SM = pd.DataFrame(df[df['Marketing Technique_Social media'] == 1])
df_TA = pd.DataFrame(df[df['Marketing Technique_TV ADs'] == 1])
df_B = pd.DataFrame(df[df['Marketing Technique_Blogs'] == 1])
df_P = pd.DataFrame(df[df['Marketing Technique_Posters'] == 1])
df_PR = pd.DataFrame(df[df['Marketing Technique_Public reviews'] == 1])
df_S = pd.DataFrame(df[df['Marketing Technique_Sponsorship'] == 1])

# %%
def stats(data):
    data.drop('Marketing Technique_Social media', axis = 'columns', inplace = True)
    data.drop('Marketing Technique_TV ADs', axis = 'columns', inplace = True)
    data.drop('Marketing Technique_Blogs', axis = 'columns', inplace = True)
    data.drop('Marketing Technique_Posters', axis = 'columns', inplace = True)
    data.drop('Marketing Technique_Public reviews', axis = 'columns', inplace = True)
    data.drop('Marketing Technique_Sponsorship', axis = 'columns', inplace = True)
    sample =  pd.get_dummies(data)
    s = sample.sum(axis = 0, skipna = True)
    data1 = pd.array([s["Social Media_Average"], s["Social Media_Least"], s["Social Media_Less"], s["Social Media_More"], s["Social Media_Most"]])
    data2 = pd.array([s["Tele Marketing_Average"], s["Tele Marketing_Least"], s["Tele Marketing_Less"], s["Tele Marketing_More"], s["Tele Marketing_Most"]])
    data3 = pd.array([s["TV Ads_Average"], s["TV Ads_Least"], s["TV Ads_Less"], s["TV Ads_More"], s["TV Ads_Most"]])
    data4 = pd.array([s["Pop-up ADs_Average"], s["Pop-up ADs_Least"], s["Pop-up ADs_Less"], s["Pop-up ADs_More"], s["Pop-up ADs_Most"]])
    data5 = pd.array([s["Posters_Average"], s["Posters_Least"], s["Posters_Less"], s["Posters_More"], s["Posters_Most"]])
    X = np.arange(5)
    data = pd.array(["Average", "Least", "Less", "More", "Most"])
    plt.figure(figsize = (10, 10))
    plt.bar(X + 0.00, data1, label = "Scoial Media", color = 'b', width = 0.10)
    plt.bar(X + 0.15, data2, label = "Tele Marketing", color = 'g', width = 0.10)
    plt.bar(X + 0.30, data3, label = "TV ADs", color = 'r', width = 0.10)
    plt.bar(X + 0.45, data4, label = "Pop-up ADs", color = 'orange', width = 0.10)
    plt.bar(X + 0.60, data5, label = "Posters", color = 'y', width = 0.10)
    plt.xticks(X, data)
    plt.legend()
    plt.show()

# %%
stats(df_SM)

# %%
stats(df_TA)

# %%
stats(df_B)

# %%
stats(df_P)

# %%
stats(df_PR)

# %%
stats(df_S)
